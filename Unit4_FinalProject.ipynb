# %% [markdown]
# # Making a CMD for your Star Cluster
#
# This notebook introduces a few commands that you'll need to make the Color Magnitude Diagram for your star cluster. You can also use the cells below to write code for your unit project.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("oh_table.csv")

# %%
df.head()
# Out:
#    row_id     tgas_source_id             name         ra        dec  parallax  \
# 0     659  49809491645958528   TYC 1253-388-1  59.457281  18.562195    7.7395
# 1    1559  66939848447027584  TYC 1804-1924-1  57.070387  25.214932    7.6087
# 2    1904  50905051903831680        HIP 18091  58.003444  19.596690    6.7611
# 3    1929  51452746133437696        HIP 18544  59.507154  20.676596    7.6989
# 4    1944  51619115986889472  TYC 1261-1630-1  58.370320  20.907178    7.4847
#
#    distance       G       J           rave_obs_id    rv  erv  group_id  \
# 0   129.949  11.160   9.984                   NaN   NaN  NaN         0
# 1   132.557   9.066   8.137  20120109_0346p23_140  2.95  1.6         0
# 2   148.752  10.265   9.267                   NaN   NaN  NaN         0
# 3   131.839   9.249   8.436                   NaN   NaN  NaN         0
# 4   134.194  11.553  10.096                   NaN   NaN  NaN         0
#
#    group_size
# 0         151
# 1         151
# 2         151
# 3         151
# 4         151

# %%
new_df = df.loc[df["group_id"]==1]
new_df.head()
# Out:
#      row_id      tgas_source_id             name         ra        dec  \
# 151    4215  230386718682382976  TYC 2885-2209-1  60.473140  41.727862
# 152    4381  231698848371132032        HIP 18507  59.357595  43.316188
# 153    4418  231907240183865600        HIP 18640  59.852732  44.481590
# 154    4439  232078592199612416  TYC 2886-2075-1  62.971059  42.749205
# 155    4447  232143188507760128  TYC 2890-2306-1  63.436792  43.566124
#
#      parallax  distance       G      J rave_obs_id  rv  erv  group_id  \
# 151    6.5020   155.458  10.276  9.380         NaN NaN  NaN         1
# 152    7.2032   140.343   7.372  7.240         NaN NaN  NaN         1
# 153    6.1964   162.826   7.930  7.642         NaN NaN  NaN         1
# 154    6.8740   146.798   8.823  7.987         NaN NaN  NaN         1
# 155    6.5555   154.674  10.054  9.090         NaN NaN  NaN         1
#
#      group_size
# 151         125
# 152         125
# 153         125
# 154         125
# 155         125

# %% [markdown]
# ## .loc[ ] indexing

# %%
# Here we create a sample dataframe
sample_df = pd.DataFrame({"column 1": [20,50,15,50,65,50,10], "column 2": [0,1,1,1,0,0,1]})
sample_df
# Out:
#    column 1  column 2
# 0        20         0
# 1        50         1
# 2        15         1
# 3        50         1
# 4        65         0
# 5        50         0
# 6        10         1

# %% [markdown]
# You can use the .loc index method to select all the items in one column which have a particular value in the second column. For example, we may want to select all items from column 1 that have a value of 0 in column 2.
#
# Follow along with the live coding activity to see how this works.

# %%
# This code selects all values from column 1 where the value on that same row in column 2 is equal to 0
zeros = sample_df["column 1"].loc[sample_df["column 2"] == 0]
zeros
# Out:
# 0    20
# 4    65
# 5    50
# Name: column 1, dtype: int64

# %%
sample_df20 = sample_df.loc[sample_df["column 1"] < 30]
sample_df20.head()
# Out:
#    column 1  column 2
# 0        20         0
# 2        15         1
# 6        10         1

# %% [markdown]
# Now you try! Select all the values from column 1 where the value on that same row in column 2 is equal to 1.

# %%
sample_df2 = sample_df["column 1"].loc[sample_df["column 2"] == 1]
sample_df2.head()
# Out:
# 1    50
# 2    15
# 3    50
# 6    10
# Name: column 1, dtype: int64

# %% [markdown]
# Now select all the values from column 2 where the value on that same row in column 1 is equal to 50.

# %%
sample_df1 = sample_df["column 2"].loc[sample_df["column 1"] ==50]
sample_df1.head()
# Out:
# 1    1
# 3    1
# 5    0
# Name: column 2, dtype: int64

# %% [markdown]
# #### Note: You can store these selected values in a variable, just like you've done with entire columns!

# %% [markdown]
# ## Finding absolute magnitude

# %% [markdown]
# You will need to convert "G" to absolute magnitude for your CMD.
#
# Look in the dataset for distance. Using G and distance, you can calculate absolute magnitude using the following equation:
#
# absolute magnitude = G - 5 * log(distance) + 5

# %%
# You will need to import numpy
import numpy as np
import matplotlib.colors as mpl # We'll use the matplotlib.colors library to color our data points
# %matplotlib inline

# %%
# You can use this function in your code to find the log of distance:
new_df["Absolute Magnitude"] = new_df["G"]-5*np.log10(new_df["distance"])+5
new_df.head(125)
# np.log10()
# Out:
# /Users/brownscholar/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      row_id      tgas_source_id             name         ra        dec  \
# 151    4215  230386718682382976  TYC 2885-2209-1  60.473140  41.727862
# 152    4381  231698848371132032        HIP 18507  59.357595  43.316188
# 153    4418  231907240183865600        HIP 18640  59.852732  44.481590
# 154    4439  232078592199612416  TYC 2886-2075-1  62.971059  42.749205
# 155    4447  232143188507760128  TYC 2890-2306-1  63.436792  43.566124
# 156    4656  244633881118838016        HIP 16980  54.594695  44.800400
# 157    4862  244858078409820032  TYC 3313-2328-1  55.910643  46.063101
# 158    5127  237515471042152448        HIP 16938  54.500874  42.582741
# 159    5198  238122229660749312        HIP 16258  52.384099  43.230600
# 160    5232  238329109644585216        HIP 16964  54.564409  43.481649
# 161    5277  238639859120133376  TYC 2874-1222-1  53.300583  44.156766
# 162    5675  241604211186360064   TYC 2873-873-1  52.014254  44.339443
# 163    5698  241699525101944576   TYC 2874-438-1  53.399442  44.870752
# 164    5889  242888956163684096        HIP 16252  52.359669  46.937759
# 165    5891  233087016161261824  TYC 2889-1143-1  60.924507  43.937171
# 166    5913  243068657596900224        HIP 15971  51.407051  47.020538
# 167    5917  243096832581342848        HIP 16036  51.636210  47.266316
# 168    5919  243137067835529344        HIP 15911  51.229804  47.414913
# 169    5920  441849158625581568  TYC 3320-1768-1  51.407022  50.321545
# 170    5924  243190978263909632  TYC 3316-1812-1  51.372943  47.967214
# 171    5926  243197094297988608        HIP 17549  56.379566  42.006794
# 172    5965  243650127447860096        HIP 17681  56.817335  44.073595
# 173    6032  244263586216575616        HIP 18214  58.414664  45.758015
# 174    6081  244596497721602176        HIP 17577  56.471935  45.599823
# 175    6090  244690574687138688   TYC 2874-378-1  54.198620  44.886282
# 176    6101  244788843539087104  TYC 3326-2214-1  56.372704  45.741983
# 177    6172  245189890404732160  TYC 3326-2163-1  56.431124  46.301091
# 178    6344  246596887329673728  TYC 3330-2390-1  58.950334  47.040224
# 179    6494  247787692782638976  TYC 3313-2708-1  53.574697  45.729966
# 180    6531  248077998211731840  TYC 3312-1412-1  53.194372  46.700762
# ..      ...                 ...              ...        ...        ...
# 246    8771  441454914984502656        HIP 15878  51.125304  49.139801
# 247    8773  441463607998311808        HIP 15988  51.489243  49.120647
# 248    8774  441480409912850432   TYC 3320-805-1  51.291927  49.251434
# 249    8775  441481165827089024  TYC 3320-1449-1  51.336490  49.316065
# 250    8777  441486044909931136   TYC 3320-545-1  51.592763  49.426980
# 251    8779  441493775848573440  TYC 3320-1057-1  52.354146  48.962417
# 252    8780  441494188165433216  TYC 3320-1849-1  52.445407  49.009397
# 253    8784  441519064618374656   TYC 3320-565-1  52.158415  49.387529
# 254    8788  441550125819632768        HIP 16403  52.811309  49.706138
# 255    8790  441558440876307584        HIP 16455  52.994822  49.870054
# 256    8796  441582114738266368        HIP 16118  51.912515  49.599812
# 257    8797  441585722510785408  TYC 3320-2239-1  51.979387  49.760220
# 258    8800  441597954577636608   TYC 3320-686-1  52.077572  49.952767
# 259    8813  441645233577061248        HIP 15862  51.080076  49.221156
# 260    8814  441653239394337024  TYC 3319-1538-1  50.494392  49.214762
# 261    8822  441696326507978752  TYC 3320-2058-1  51.268323  49.795295
# 262    8837  441780164270958464   TYC 3320-818-1  51.683144  49.909448
# 263    8843  441815142481538048   TYC 3320-804-1  52.144565  50.266768
# 264    8898  442036934595519872   TYC 3325-239-1  53.771075  50.912436
# 265    8899  442041985477060480   TYC 3325-442-1  53.495680  50.882143
# 266    8917  442265083255962624        HIP 16506  53.133028  51.489483
# 267    8940  442556556916042496   TYC 3319-219-1  49.682212  50.386156
# 268    8943  442576794801933312        HIP 15388  49.599783  50.555596
# 269    8945  442609127315775744        HIP 15531  50.026248  50.968655
# 270    8964  442750826879003648        HIP 15814  50.929987  51.770256
# 271    8972  442841914544333696        HIP 15259  49.204723  51.218088
# 272    8982  442921800934903424        HIP 15556  50.098781  51.618251
# 273    9041  443683693773493504   TYC 3325-814-1  55.143989  52.008284
# 274    9213  445951986261569280        HIP 14845  47.928919  52.163362
# 275   10227  441901694662492928        HIP 16047  51.664527  50.846396
#
#      parallax  distance       G       J rave_obs_id  rv  erv  group_id  \
# 151    6.5020   155.458  10.276   9.380         NaN NaN  NaN         1
# 152    7.2032   140.343   7.372   7.240         NaN NaN  NaN         1
# 153    6.1964   162.826   7.930   7.642         NaN NaN  NaN         1
# 154    6.8740   146.798   8.823   7.987         NaN NaN  NaN         1
# 155    6.5555   154.674  10.054   9.090         NaN NaN  NaN         1
# 156    7.3550   137.214   7.566   7.302         NaN NaN  NaN         1
# 157    6.8421   147.702  11.489  10.198         NaN NaN  NaN         1
# 158    5.9207   175.604   6.423   6.461         NaN NaN  NaN         1
# 159    5.5551   181.486   8.822   8.273         NaN NaN  NaN         1
# 160    6.8181   147.477   8.540   8.001         NaN NaN  NaN         1
# 161    7.0392   143.138   9.372   8.556         NaN NaN  NaN         1
# 162    7.8000   128.625   8.470   7.717         NaN NaN  NaN         1
# 163    5.7675   175.149  10.210   9.337         NaN NaN  NaN         1
# 164    6.1075   169.398   6.186   5.875         NaN NaN  NaN         1
# 165    6.6515   151.473   8.532   7.982         NaN NaN  NaN         1
# 166    5.8537   172.478   8.903   8.377         NaN NaN  NaN         1
# 167    6.1874   163.744   8.166   7.797         NaN NaN  NaN         1
# 168    5.8264   172.686   9.598   8.829         NaN NaN  NaN         1
# 169    5.4135   187.762   9.913   8.900         NaN NaN  NaN         1
# 170    5.7929   174.161   9.140   8.369         NaN NaN  NaN         1
# 171    6.4972   158.527   6.918   6.885         NaN NaN  NaN         1
# 172    7.2580   139.429   7.084   7.021         NaN NaN  NaN         1
# 173    5.4932   184.621   8.552   8.153         NaN NaN  NaN         1
# 174    6.2197   162.655   7.602   7.400         NaN NaN  NaN         1
# 175    6.2407   161.926  10.974   9.883         NaN NaN  NaN         1
# 176    6.2145   162.296  11.511  10.267         NaN NaN  NaN         1
# 177    5.3411   189.220  11.820  10.520         NaN NaN  NaN         1
# 178    5.4523   184.683  10.480   9.501         NaN NaN  NaN         1
# 179    5.6807   177.605  11.278  10.082         NaN NaN  NaN         1
# 180    5.4017   186.672   9.705   8.880         NaN NaN  NaN         1
# ..        ...       ...     ...     ...         ...  ..  ...       ...
# 246    5.6657   177.995   7.891   7.705         NaN NaN  NaN         1
# 247    5.9706   170.835   6.106   6.198         NaN NaN  NaN         1
# 248    5.8037   173.822   8.157   7.887         NaN NaN  NaN         1
# 249    5.8201   173.364   8.403   8.037         NaN NaN  NaN         1
# 250    5.6926   178.118  11.097   9.900         NaN NaN  NaN         1
# 251    5.6823   177.427  10.111   9.199         NaN NaN  NaN         1
# 252    5.8468   172.172   9.047   8.153         NaN NaN  NaN         1
# 253    5.5155   183.927   8.409   8.070         NaN NaN  NaN         1
# 254    5.3583   188.505   8.582   8.185         NaN NaN  NaN         1
# 255    5.4858   183.945   9.089   8.382         NaN NaN  NaN         1
# 256    5.6778   179.737   6.963   6.892         NaN NaN  NaN         1
# 257    5.6730   177.294  10.474   9.482         NaN NaN  NaN         1
# 258    5.9312   170.339   8.100   7.649         NaN NaN  NaN         1
# 259    5.6619   177.988   8.903   8.293         NaN NaN  NaN         1
# 260    5.8557   172.775   9.081   8.483         NaN NaN  NaN         1
# 261    5.5266   183.152   8.953   8.337         NaN NaN  NaN         1
# 262    5.7306   176.091  10.672   9.632         NaN NaN  NaN         1
# 263    5.6757   178.054   9.904   8.975         NaN NaN  NaN         1
# 264    5.5654   184.669  11.047   9.900         NaN NaN  NaN         1
# 265    5.6447   178.511   9.747   8.873         NaN NaN  NaN         1
# 266    5.7851   175.221  10.037   9.137         NaN NaN  NaN         1
# 267    6.0803   165.898  10.105   9.109         NaN NaN  NaN         1
# 268    5.8214   173.532   8.014   7.584         NaN NaN  NaN         1
# 269    5.8463   174.049   7.070   6.910         NaN NaN  NaN         1
# 270    6.1850   163.401   7.871   7.599         NaN NaN  NaN         1
# 271    5.1805   195.788   7.195   6.983         NaN NaN  NaN         1
# 272    6.0204   168.288   7.299   7.182         NaN NaN  NaN         1
# 273    5.6740   178.301   9.076   8.454         NaN NaN  NaN         1
# 274    5.4545   186.586   6.899   6.806         NaN NaN  NaN         1
# 275    5.7805   175.144   7.633   7.347         NaN NaN  NaN         1
#
#      group_size  Absolute Magnitude
# 151         125            4.317935
# 152         125            1.636046
# 153         125            1.871381
# 154         125            2.989399
# 155         125            4.106913
# 156         125            1.879008
# 157         125            5.642068
# 158         125            0.200328
# 159         125            2.527784
# 160         125            2.696379
# 161         125            3.593225
# 162         125            2.923373
# 163         125            3.992962
# 164         125            0.041459
# 165         125            2.630324
# 166         125            2.719331
# 167         125            2.095173
# 168         125            3.411714
# 169         125            3.544961
# 170         125            2.935245
# 171         125            0.917484
# 172         125            1.362234
# 173         125            2.220595
# 174         125            1.545663
# 175         125            4.927417
# 176         125            5.459461
# 177         125            5.435165
# 178         125            4.147865
# 179         125            5.030724
# 180         125            3.349604
# ..          ...                 ...
# 246         125            1.638961
# 247         125           -0.056884
# 248         125            1.956476
# 249         125            2.208205
# 250         125            4.843461
# 251         125            3.865901
# 252         125            2.867187
# 253         125            2.085773
# 254         125            2.205386
# 255         125            2.765560
# 256         125            0.689813
# 257         125            4.230530
# 258         125            1.943430
# 259         125            2.651046
# 260         125            2.893595
# 261         125            2.638942
# 262         125            4.443314
# 263         125            3.651241
# 264         125            4.715030
# 265         125            3.488675
# 266         125            3.819069
# 267         125            4.005794
# 268         125            1.817102
# 269         125            0.866642
# 270         125            1.804726
# 271         125            0.736070
# 272         125            1.168734
# 273         125            2.820231
# 274         125            0.544605
# 275         125            1.416024
#
# [125 rows x 15 columns]

# %% [markdown]
# ### Your first task is to create a Color Magnitude Diagram for your star cluster
# You can use as many of the cells below as you need. You can add new cells with the "+" button.

# %%
new_df["Color"] = new_df["G"]-new_df["J"]
new_df.head(5)
# Out:
# /Users/brownscholar/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      row_id      tgas_source_id             name         ra        dec  \
# 151    4215  230386718682382976  TYC 2885-2209-1  60.473140  41.727862
# 152    4381  231698848371132032        HIP 18507  59.357595  43.316188
# 153    4418  231907240183865600        HIP 18640  59.852732  44.481590
# 154    4439  232078592199612416  TYC 2886-2075-1  62.971059  42.749205
# 155    4447  232143188507760128  TYC 2890-2306-1  63.436792  43.566124
#
#      parallax  distance       G      J rave_obs_id  rv  erv  group_id  \
# 151    6.5020   155.458  10.276  9.380         NaN NaN  NaN         1
# 152    7.2032   140.343   7.372  7.240         NaN NaN  NaN         1
# 153    6.1964   162.826   7.930  7.642         NaN NaN  NaN         1
# 154    6.8740   146.798   8.823  7.987         NaN NaN  NaN         1
# 155    6.5555   154.674  10.054  9.090         NaN NaN  NaN         1
#
#      group_size  Absolute Magnitude  Color
# 151         125            4.317935  0.896
# 152         125            1.636046  0.132
# 153         125            1.871381  0.288
# 154         125            2.989399  0.836
# 155         125            4.106913  0.964

# %%
C = new_df["Color"]
AM = new_df["Absolute Magnitude"]
D = "distance"

# %%
SunJ = 3.64
SunG = 5.12

# %%
cm = plt.cm.get_cmap("Blues_r")
plt.scatter(new_df["G"]- new_df["J"], new_df["Absolute Magnitude"],c=C, s=35, cmap=cm,norm=mpl.LogNorm())
plt.scatter(SunG-SunJ,SunG, c='gold', s=400, marker='*', edgecolors = "black")
plt.xlabel = ("G-J")
plt.ylabel = ("Absolute Magnitude")
plt.title('Color Magnitude Diagram')
#plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
ax = plt.gca()
ax.set_facecolor('xkcd:black')

# %% [markdown]
# ### Coding Challenge 1: Add the sun to your color magnitude diagram

# %% [markdown]
# ### Coding Challenge 2: Add a colormap to your diagram

# %% [markdown]
# ### Coding Challenge 3: Create histograms for the absolute magnitude and color of your star cluster

# %%
plt.title(("Distance"))
cm = plt.cm.get_cmap("winter")

n, bins, patches = plt.hist(new_df["distance"])
bin_centers = 0.5 * (bins[:-1] + bins[1:])

col = bin_centers - min(bin_centers)
col /= max(col)
for c, p in zip(col, patches):
    plt.setp(p, "facecolor", cm(c))

plt.show()
